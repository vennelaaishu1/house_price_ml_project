# %%
# ==============================
# REQUIRED LIBRARIES
# ==============================

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import joblib

# Train/Test Split
from sklearn.model_selection import train_test_split

# Preprocessing
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, StandardScaler

# Regression Models
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor

# Evaluation Metrics
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Display settings
pd.set_option("display.max_columns", None)

print("All required libraries imported successfully!")
# Out:
# All required libraries imported successfully!

# %%
test_df = pd.read_csv(
    r"C:\Users\Aishwarya\Downloads\house-prices-advanced-regression-techniques\test.csv"
)

print("Test data shape:", test_df.shape)
test_df.head()
# Out:
# Test data shape: (1459, 80)
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl        NAmes      Feedr
# 1         Lvl    AllPub    Corner       Gtl        NAmes       Norm
# 2         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 3         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 4         HLS    AllPub    Inside       Gtl      StoneBr       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
print("Number of columns:", len(test_df.columns))
print("SalePrice present:", "SalePrice" in test_df.columns)
# Out:
# Number of columns: 80
# SalePrice present: False

# %%
test_data = test_df.copy()

# %%
none_cols = [
    "PoolQC", "MiscFeature", "Alley", "Fence", "MasVnrType",
    "FireplaceQu", "GarageType", "GarageFinish", "GarageQual",
    "GarageCond", "BsmtExposure", "BsmtFinType2", "BsmtQual",
    "BsmtCond", "BsmtFinType1"
]

test_data[none_cols] = test_data[none_cols].fillna("None")

# %%
test_data["LotFrontage"] = (
    test_data.groupby("Neighborhood")["LotFrontage"]
    .transform(lambda x: x.fillna(x.median()))
)

test_data["GarageYrBlt"] = test_data["GarageYrBlt"].fillna(0)

test_data["MasVnrArea"] = test_data["MasVnrArea"].fillna(0)

test_data["Electrical"] = (
    test_data["Electrical"].fillna(
        test_data["Electrical"].mode()[0]
    )
)

print("Remaining missing values:")
print(test_data.isnull().sum().sum())
# Out:
# Remaining missing values:
# 22

# %%
test_data["TotalSF"] = (
    test_data["TotalBsmtSF"].fillna(0)
    + test_data["1stFlrSF"].fillna(0)
    + test_data["2ndFlrSF"].fillna(0)
)

test_data["TotalBathrooms"] = (
    test_data["FullBath"].fillna(0)
    + 0.5 * test_data["HalfBath"].fillna(0)
    + test_data["BsmtFullBath"].fillna(0)
    + 0.5 * test_data["BsmtHalfBath"].fillna(0)
)

test_data["TotalPorchSF"] = (
    test_data["OpenPorchSF"].fillna(0)
    + test_data["3SsnPorch"].fillna(0)
    + test_data["EnclosedPorch"].fillna(0)
    + test_data["ScreenPorch"].fillna(0)
    + test_data["WoodDeckSF"].fillna(0)
)

test_data["HouseAge"] = (
    test_data["YrSold"] - test_data["YearBuilt"]
)

test_data["YearsSinceRemodel"] = (
    test_data["YrSold"] - test_data["YearRemodAdd"]
)

print("Test shape after feature engineering:", test_data.shape)
# Out:
# Test shape after feature engineering: (1459, 85)

# %%
X_test_final = test_data.drop(columns=["Id"])

print("Final test feature shape:", X_test_final.shape)
# Out:
# Final test feature shape: (1459, 84)

# %%
loaded_model = joblib.load(
    "model/house_price_model.pkl"
)

print("Saved model loaded successfully!")
# Out:
# Saved model loaded successfully!

# %%
test_predictions = loaded_model.predict(X_test_final)

print("Number of predictions:", len(test_predictions))
# Out:
# Number of predictions: 1459

# %%
submission = pd.DataFrame({
    "Id": test_df["Id"],
    "SalePrice": test_predictions
})

display(submission.head(10))
# Out:
#      Id      SalePrice
# 0  1461  124903.233600
# 1  1462  162959.020236
# 2  1463  182987.427407
# 3  1464  186761.438830
# 4  1465  179348.083659
# 5  1466  176632.416069
# 6  1467  182481.814647
# 7  1468  166172.359468
# 8  1469  186791.763330
# 9  1470  124950.488965

# %%
submission.to_csv(
    "predictions.csv",
    index=False
)

print("predictions.csv created successfully!")
# Out:
# predictions.csv created successfully!

# %%
print("Prediction file shape:", submission.shape)

print("\nPrediction columns:")
print(submission.columns.tolist())

print("\nPrediction statistics:")
display(submission["SalePrice"].describe())
# Out:
# Prediction file shape: (1459, 2)
#
# Prediction columns:
# ['Id', 'SalePrice']
#
# Prediction statistics:
# count      1459.000000
# mean     178892.586085
# std       75869.804344
# min       40656.407854
# 25%      127872.713881
# 50%      157022.807110
# 75%      208741.776902
# max      613892.600058
# Name: SalePrice, dtype: float64
